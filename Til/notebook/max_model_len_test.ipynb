# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import nest_asyncio
import uuid
import torch
from vllm import AsyncEngineArgs, AsyncLLMEngine, SamplingParams
from transformers import AutoTokenizer
from pprint import pprint
import os
import json
import re

from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct

from langgraph.graph import StateGraph
from langsmith import traceable

from typing_extensions import TypedDict 

from pydantic import BaseModel, Field
from typing import List, Dict, Optional, Annotated

from transformers import AutoTokenizer, AutoModel


# 이벤트 루프 충돌 방지
nest_asyncio.apply()
# Out:
# INFO 05-18 15:14:42 [__init__.py:239] Automatically detected platform cuda.

# %%
gemma = os.getenv("GEMMA_MODEL_4B_PATH")
tokenizer = AutoTokenizer.from_pretrained("google/gemma-3-4b-it")

engine_args = AsyncEngineArgs(
    model=gemma,
    # tokenizer = tokenizer,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.95,
    # max_num_seqs = 100,
    max_model_len=16384,
    max_num_batched_tokens=8192
)
llm = AsyncLLMEngine.from_engine_args(engine_args)
# Out:
# INFO 05-18 15:14:56 [config.py:600] This model supports multiple tasks: {'reward', 'score', 'generate', 'embed', 'classify'}. Defaulting to 'generate'.
# INFO 05-18 15:14:57 [config.py:1780] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 05-18 15:15:01 [core.py:61] Initializing a V1 LLM engine (v0.8.3) with config: model='/home/a01088415234/models/gemma-3-4b-it/', speculative_config=None, tokenizer='/home/a01088415234/models/gemma-3-4b-it/', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=16384, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=None, served_model_name=/home/a01088415234/models/gemma-3-4b-it/, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"custom_ops":["none"],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}
# WARNING 05-18 15:15:01 [utils.py:2413] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x7f3dccadd4b0>
# INFO 05-18 15:15:02 [parallel_state.py:957] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 05-18 15:15:02 [cuda.py:221] Using Flash Attention backend on V1 engine.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# INFO 05-18 15:15:12 [gpu_model_runner.py:1258] Starting to load model /home/a01088415234/models/gemma-3-4b-it/...
# INFO 05-18 15:15:12 [config.py:3334] cudagraph sizes specified by model runner [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 264, 272, 280, 288, 296, 304, 312, 320, 328, 336, 344, 352, 360, 368, 376, 384, 392, 400, 408, 416, 424, 432, 440, 448, 456, 464, 472, 480, 488, 496, 504, 512] is overridden by config [512, 384, 256, 128, 4, 2, 1, 392, 264, 136, 8, 400, 272, 144, 16, 408, 280, 152, 24, 416, 288, 160, 32, 424, 296, 168, 40, 432, 304, 176, 48, 440, 312, 184, 56, 448, 320, 192, 64, 456, 328, 200, 72, 464, 336, 208, 80, 472, 344, 216, 88, 120, 480, 352, 248, 224, 96, 488, 504, 360, 232, 104, 496, 368, 240, 112, 376]
# WARNING 05-18 15:15:12 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 05-18 15:15:15 [loader.py:447] Loading weights took 2.59 seconds
# INFO 05-18 15:15:15 [gpu_model_runner.py:1273] Model loading took 8.5828 GiB and 2.872397 seconds
# INFO 05-18 15:15:15 [gpu_model_runner.py:1542] Encoder cache will be initialized with a budget of 8192 tokens, and profiled with 32 image items of the maximum feature size.
# INFO 05-18 15:15:38 [backends.py:416] Using cache directory: /home/a01088415234/.cache/vllm/torch_compile_cache/7948162d1b/rank_0_0 for vLLM's torch.compile
# INFO 05-18 15:15:38 [backends.py:426] Dynamo bytecode transform time: 16.94 s
# INFO 05-18 15:15:39 [backends.py:115] Directly load the compiled graph for shape None from the cache
# INFO 05-18 15:15:52 [monitor.py:33] torch.compile takes 16.94 s in total
# INFO 05-18 15:15:54 [kv_cache_utils.py:578] GPU KV cache size: 11,024 tokens
# INFO 05-18 15:15:54 [kv_cache_utils.py:581] Maximum concurrency for 16,384 tokens per request: 0.67x
# INFO 05-18 15:16:30 [gpu_model_runner.py:1608] Graph capturing finished in 36 secs, took 0.55 GiB
# INFO 05-18 15:16:30 [core.py:162] init engine (profile, create kv cache, warmup model) took 75.00 seconds

# %%
sampling_params = SamplingParams(temperature=0.6, top_p=0.7, repetition_penalty=1.1, max_tokens=4096, stop = ["<eos>"])


# 비동기 LLM 실행 (non-streaming)
async def llm_engine(prompt: str) -> str:
    request_id = str(uuid.uuid4())
    last_output = None

    async for output in llm.generate(
        prompt=prompt,
        sampling_params=sampling_params,
        request_id=request_id
    ):
        last_output = output.outputs[0].text  # ✅ 덮어쓰기만 함

    return last_output if last_output is not None else ""



async def llm_til(prompt: str) -> str:
    try:
        result = await llm_engine(prompt)
        return result
    except Exception as e:
        print(f"❌ LLM 호출 실패: {e}")
        return "[LLM 호출 실패]"

# %%
# JSON 파일 읽기
with open("/home/a01088415234/models/data/dia_230520.json", 'r', encoding='utf-8') as file:
    data = json.load(file)
data
# Out:
# {'username': 'kingwhangzang',
#  'date': '2023-05-22',
#  'repo': 'IPS',
#  'files': [{'filepath': 'Map.js',
#    'latest_code': 'import React, { useEffect, useState } from \'react\';\nimport { NavLink } from \'react-router-dom\';\nimport ReviewAndInfo from \'./ReviewAndInfo\'; \n\nconst { kakao } = window;\n\nfunction Map() {\n  const [selectedStore, setSelectedStore] = useState(null);\n\n  const handleLogout = () => {\n    // Logout logic implementation\n  };\n\n  useEffect(() => {\n    const container = document.getElementById(\'map\');\n    const options = {\n      center: new kakao.maps.LatLng(37.365264512305174, 127.10676860117488),\n      level: 3\n    };\n    const map = new kakao.maps.Map(container, options);\n\n    const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321);\n    const marker = new kakao.maps.Marker({\n      position: markerPosition\n    });\n\n    kakao.maps.event.addListener(marker, \'click\', function() {\n      setSelectedStore({\n        name: \'가맹점 이름\',\n        review: \'리뷰 내용\',\n        info: \'가맹점 정보\'\n      });\n    });\n    marker.setMap(map);\n  }, []);\n\n  return (\n    <div>\n      <nav className="dashboard-nav">\n        <ul>\n          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n          <li className=\'sook\'>쑥쑥카드</li>\n          <li>\n            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n          </li>\n          <li>\n            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n          </li>\n          <li>\n            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n          </li>\n          <li>\n            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n          </li>\n          <li>\n            <button onClick={handleLogout}>Logout</button>\n          </li>\n        </ul>\n      </nav>\n\n      <div id="map" style={{ width: "1000px", height: "400px" }}></div>\n\n      {selectedStore && (\n        <ReviewAndInfo\n          name={selectedStore.name}\n          review={selectedStore.review}\n          info={selectedStore.info}\n        />\n      )}\n    </div>\n  );\n}\n\nexport default Map;',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -1,42 +1,72 @@\n-//eslint-disable-next-line\n-/* global kakao */\n import React, { useEffect, useState } from \'react\';\n+import { NavLink } from \'react-router-dom\';\n import ReviewAndInfo from \'./ReviewAndInfo\'; \n \n-const {kakao} = window;\n+const { kakao } = window;\n \n-function Map(){\n+function Map() {\n   const [selectedStore, setSelectedStore] = useState(null);\n \n-  useEffect(()=>{\n+  const handleLogout = () => {\n+    // Logout logic implementation\n+  };\n+\n+  useEffect(() => {\n     const container = document.getElementById(\'map\');\n     const options = {\n       center: new kakao.maps.LatLng(37.365264512305174, 127.10676860117488),\n       level: 3\n     };\n-    //eslint-disable-next-line\n-    const map = new kakao.maps.Map(container, options); \n-\n-    const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321); \n-        const marker = new kakao.maps.Marker({ \n-          position: markerPosition\n-        }); \n-\n-        kakao.maps.event.addListener(marker, \'click\', function() {\n-          setSelectedStore({\n-            name: \'가맹점 이름\',  // 가맹점의 실제 이름으로 대체하세요.\n-            review: \'리뷰 내용\', // 실제 리뷰 내용으로 대체하세요.\n-            info: \'가맹점 정보\'   // 실제 가맹점 정보로 대체하세요.\n-          });\n-        });\n-        marker.setMap(map); \n-    }, [])\n-\n-\n-    return (\n-      <div>\n-      <div id="map" style={{width:"2000px", height:"800px"}}></div>\n-      {selectedStore && <ReviewAndInfo name={selectedStore.name} review={selectedStore.review} info={selectedStore.info} />}\n+    const map = new kakao.maps.Map(container, options);\n+\n+    const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321);\n+    const marker = new kakao.maps.Marker({\n+      position: markerPosition\n+    });\n+\n+    kakao.maps.event.addListener(marker, \'click\', function() {\n+      setSelectedStore({\n+        name: \'가맹점 이름\',\n+        review: \'리뷰 내용\',\n+        info: \'가맹점 정보\'\n+      });\n+    });\n+    marker.setMap(map);\n+  }, []);\n+\n+  return (\n+    <div>\n+      <nav className="dashboard-nav">\n+        <ul>\n+          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n+          <li className=\'sook\'>쑥쑥카드</li>\n+          <li>\n+            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n+          </li>\n+          <li>\n+            <button onClick={handleLogout}>Logout</button>\n+          </li>\n+        </ul>\n+      </nav>\n+\n+      <div id="map" style={{ width: "1000px", height: "400px" }}></div>\n+\n+      {selectedStore && (\n+        <ReviewAndInfo\n+          name={selectedStore.name}\n+          review={selectedStore.review}\n+          info={selectedStore.info}\n+        />\n+      )}\n     </div>\n   );\n }'},
#     {'commit_message': 'Update Map.js',
#      'patch': '@@ -1,11 +1,42 @@\n-import React from \'react\';\n+//eslint-disable-next-line\n+/* global kakao */\n+import React, { useEffect, useState } from \'react\';\n+import ReviewAndInfo from \'./ReviewAndInfo\'; \n \n-function Map() {\n+const {kakao} = window;\n \n-  \n-  return (\n-    <div>\n-      <h1>가맹점 지도 조회</h1>\n+function Map(){\n+  const [selectedStore, setSelectedStore] = useState(null);\n+\n+  useEffect(()=>{\n+    const container = document.getElementById(\'map\');\n+    const options = {\n+      center: new kakao.maps.LatLng(37.365264512305174, 127.10676860117488),\n+      level: 3\n+    };\n+    //eslint-disable-next-line\n+    const map = new kakao.maps.Map(container, options); \n+\n+    const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321); \n+        const marker = new kakao.maps.Marker({ \n+          position: markerPosition\n+        }); \n+\n+        kakao.maps.event.addListener(marker, \'click\', function() {\n+          setSelectedStore({\n+            name: \'가맹점 이름\',  // 가맹점의 실제 이름으로 대체하세요.\n+            review: \'리뷰 내용\', // 실제 리뷰 내용으로 대체하세요.\n+            info: \'가맹점 정보\'   // 실제 가맹점 정보로 대체하세요.\n+          });\n+        });\n+        marker.setMap(map); \n+    }, [])\n+\n+\n+    return (\n+      <div>\n+      <div id="map" style={{width:"2000px", height:"800px"}}></div>\n+      {selectedStore && <ReviewAndInfo name={selectedStore.name} review={selectedStore.review} info={selectedStore.info} />}\n     </div>\n   );\n }'}]},
#   {'filepath': 'ReviewAndInfo.js',
#    'latest_code': "import React from 'react';\n\nfunction ReviewAndInfo({ name, review, info }) {\n  return (\n    <div>\n      <h2>{name}</h2>\n      <p>{review}</p>\n      <p>{info}</p>\n    </div>\n  );\n}\n\nexport default ReviewAndInfo;",
#    'patches': [{'commit_message': 'Create ReviewAndInfo.js',
#      'patch': "@@ -0,0 +1,14 @@\n+// ReviewAndInfo.js\n+import React from 'react';\n+\n+function ReviewAndInfo({ name, review, info }) {\n+  return (\n+    <div>\n+      <h2>{name}</h2>\n+      <p>{review}</p>\n+      <p>{info}</p>\n+    </div>\n+  );\n+}\n+\n+export default ReviewAndInfo;"}]},
#   {'filepath': '여러 마커에 클릭 이벤트 등록',
#    'latest_code': 'for (var i = 0; i < positions.length; i ++) {\n    // 마커 이미지의 이미지 크기 입니다\n    var imageSize = new kakao.maps.Size(24, 35); \n\n    // 마커 이미지를 생성합니다    \n    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);\n\n    // 마커를 생성합니다\n    var element = new kakao.maps.Marker({\n        map: map, // 마커를 표시할 지도\n        position: positions[i].latlng, // 마커를 표시할 위치\n        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다\n        image : markerImage // 마커 이미지 \n    }); \n    marker.push(element); // 마커 리스트에 개별 요소 추가\n}\n\n// 아래 코드는 위의 마커를 생성하는 코드에서 clickable: true 와 같이\n// 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\nmarker.setClickable(true);\n// 마커를 지도에 표시합니다.\nmarker.setMap(map);\n\n// // 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n// var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n//     iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n\n// 음식점 개별 인포윈도우 생성 \nvar iwContent = [\n    {content: \'<div style="padding:5px;">우돈갈비</div>\'},\n    {content: \'<div style="padding:5px;">갑돌네</div>\'},\n    {content: \'<div style="padding:5px;">청파 생고기</div>\'},\n],\niwRemoveable = true;\n;\n\n\n// // 인포윈도우를 생성합니다\n// var infowindow = new kakao.maps.InfoWindow({\n//     content : iwContent,\n//     removable : iwRemoveable\n// });\n\n//음식점 개별 인포윈도우 생성\nvar infowindow = []; // 빈 리스트 생성\n\nfor (var i = 0; i < positions.length; i ++) {\n  var iwelement = new kakao.maps.InfoWindow({\n    content : iwContent.content[i],\n    removable : iwRemoveable\n    });// 추가할 요소 값 생성\n  infowindow.push(iwelement); // 리스트에 요소 추가\n}\n\n// 마커에 클릭이벤트를 등록합니다\nfor (var i = 0; i < positions.length; i ++) {\n    kakao.maps.event.addListener(marker[i], \'click\', function() {\n      // 마커 위에 인포윈도우를 표시합니다\n      infowindow[i].open(map, marker[i]);  \n    });\n}\n\n</script>\n</body>\n</html>',
#    'patches': [{'commit_message': 'Delete 여러 마커에 클릭 이벤트 등록',
#      'patch': '@@ -1,99 +0,0 @@\n-<!DOCTYPE html>\n-<html>\n-<head>\n-    <meta charset="utf-8">\n-    <title>map</title>\n-</head>\n-<body>\n-<div id="map" style="width:80%;height:350px;"></div>\n-<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=92cb297775fece43f08eacb009cd81b8"></script>\n-<script>\n-var mapContainer = document.getElementById(\'map\'), // 지도를 표시할 div  \n-    mapOption = { \n-        center: new kakao.maps.LatLng(37.5445, 126.9708), // 지도의 중심좌표\n-        level: 4 // 지도의 확대 레벨\n-    };\n-var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다\n- \n-// 마커를 표시할 위치와 title 객체 배열입니다 \n-var positions = [\n-    {title: \'우돈갈비\', \n-        latlng: new kakao.maps.LatLng(37.5479, 126.9716)},\n-    {title: \'갑돌네\', \n-        latlng: new kakao.maps.LatLng(37.5502, 126.9697)},\n-    {title: \'청파 생고기\', \n-        latlng: new kakao.maps.LatLng(37.5501, 126.9697)},\n-];\n-\n-// 마커 이미지의 이미지 주소입니다\n-\n-//개별 마커 요소 생성\n-var marker = []\n-setClickable = true;\n-\n-for (var i = 0; i < positions.length; i ++) {\n-    // 마커 이미지의 이미지 크기 입니다\n-    var imageSize = new kakao.maps.Size(24, 35); \n-\n-    // 마커 이미지를 생성합니다    \n-    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);\n-\n-    // 마커를 생성합니다\n-    var element = new kakao.maps.Marker({\n-        map: map, // 마커를 표시할 지도\n-        position: positions[i].latlng, // 마커를 표시할 위치\n-        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다\n-        image : markerImage // 마커 이미지 \n-    }); \n-    marker.push(element); // 마커 리스트에 개별 요소 추가\n-}\n-\n-// 아래 코드는 위의 마커를 생성하는 코드에서 clickable: true 와 같이\n-// 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\n-marker.setClickable(true);\n-// 마커를 지도에 표시합니다.\n-marker.setMap(map);\n-\n-// // 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n-// var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n-//     iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n-\n-// 음식점 개별 인포윈도우 생성 \n-var iwContent = [\n-    {content: \'<div style="padding:5px;">우돈갈비</div>\'},\n-    {content: \'<div style="padding:5px;">갑돌네</div>\'},\n-    {content: \'<div style="padding:5px;">청파 생고기</div>\'},\n-],\n-iwRemoveable = true;\n-;\n-\n-\n-// // 인포윈도우를 생성합니다\n-// var infowindow = new kakao.maps.InfoWindow({\n-//     content : iwContent,\n-//     removable : iwRemoveable\n-// });\n-\n-//음식점 개별 인포윈도우 생성\n-var infowindow = []; // 빈 리스트 생성\n-\n-for (var i = 0; i < positions.length; i ++) {\n-  var iwelement = new kakao.maps.InfoWindow({\n-    content : iwContent.content[i],\n-    removable : iwRemoveable\n-    });// 추가할 요소 값 생성\n-  infowindow.push(iwelement); // 리스트에 요소 추가\n-}\n-\n-// 마커에 클릭이벤트를 등록합니다\n-for (var i = 0; i < positions.length; i ++) {\n-    kakao.maps.event.addListener(marker[i], \'click\', function() {\n-      // 마커 위에 인포윈도우를 표시합니다\n-      infowindow[i].open(map, marker[i]);  \n-    });\n-}\n-\n-</script>\n-</body>\n-</html>'},
#     {'commit_message': 'Update 여러 마커에 클릭 이벤트 등록',
#      'patch': '@@ -2,129 +2,98 @@\n <html>\n <head>\n     <meta charset="utf-8">\n-    <title>여러 개 마커에 클릭 이벤트 등록</title>\n-    \n+    <title>map</title>\n </head>\n <body>\n-<div id="map" style="width:100%;height:350px;"></div>\n-\n-<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey="></script>\n+<div id="map" style="width:80%;height:350px;"></div>\n+<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=92cb297775fece43f08eacb009cd81b8"></script>\n <script>\n-var mapContainer = document.getElementById(\'map\'), // 지도를 표시할 div \n+var mapContainer = document.getElementById(\'map\'), // 지도를 표시할 div  \n     mapOption = { \n-        center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표\n-        level: 3 // 지도의 확대 레벨\n+        center: new kakao.maps.LatLng(37.5445, 126.9708), // 지도의 중심좌표\n+        level: 4 // 지도의 확대 레벨\n     };\n-\n var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다\n-\n-// 가맹점 정보와 위치 넣는 방법 (1)\n-// -> 엑셀 파일의 가맹점 위치(경도 및 위도)를 불러와야 합니다.\n+ \n // 마커를 표시할 위치와 title 객체 배열입니다 \n var positions = [\n-    {\n-        title: \'A\', \n-        latlng: new kakao.maps.LatLng(33.450705, 126.570677)\n-    },\n-    {\n-        title: \'B\', \n-        latlng: new kakao.maps.LatLng(33.450936, 126.569477)\n-    },\n-    {\n-        title: \'C\', \n-        latlng: new kakao.maps.LatLng(33.450879, 126.569940)\n-    },\n+    {title: \'우돈갈비\', \n+        latlng: new kakao.maps.LatLng(37.5479, 126.9716)},\n+    {title: \'갑돌네\', \n+        latlng: new kakao.maps.LatLng(37.5502, 126.9697)},\n+    {title: \'청파 생고기\', \n+        latlng: new kakao.maps.LatLng(37.5501, 126.9697)},\n ];\n \n-// 마커를 생성합니다\n-var marker = new kakao.maps.Marker({\n-  position: position,\n-  clickable: true // 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\n-});\n+// 마커 이미지의 이미지 주소입니다\n+\n+//개별 마커 요소 생성\n+var marker = []\n+setClickable = true;\n+\n+for (var i = 0; i < positions.length; i ++) {\n+    // 마커 이미지의 이미지 크기 입니다\n+    var imageSize = new kakao.maps.Size(24, 35); \n+\n+    // 마커 이미지를 생성합니다    \n+    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);\n+\n+    // 마커를 생성합니다\n+    var element = new kakao.maps.Marker({\n+        map: map, // 마커를 표시할 지도\n+        position: positions[i].latlng, // 마커를 표시할 위치\n+        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다\n+        image : markerImage // 마커 이미지 \n+    }); \n+    marker.push(element); // 마커 리스트에 개별 요소 추가\n+}\n \n // 아래 코드는 위의 마커를 생성하는 코드에서 clickable: true 와 같이\n // 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\n-// marker.setClickable(true);\n-\n+marker.setClickable(true);\n // 마커를 지도에 표시합니다.\n marker.setMap(map);\n \n-// 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n-var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n-    iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n+// // 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n+// var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n+//     iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n \n-// 인포윈도우를 생성합니다\n-var infowindow = new kakao.maps.InfoWindow({\n-    content : iwContent,\n-    removable : iwRemoveable\n-});\n+// 음식점 개별 인포윈도우 생성 \n+var iwContent = [\n+    {content: \'<div style="padding:5px;">우돈갈비</div>\'},\n+    {content: \'<div style="padding:5px;">갑돌네</div>\'},\n+    {content: \'<div style="padding:5px;">청파 생고기</div>\'},\n+],\n+iwRemoveable = true;\n+;\n \n-// 마커에 클릭이벤트를 등록합니다\n-kakao.maps.event.addListener(marker, \'click\', function() {\n-      // 마커 위에 인포윈도우를 표시합니다\n-      infowindow.open(map, marker);  \n-});\n \n-// 가맹점 정보와 위치 넣는 방법 (2)\n-// 주소-좌표 변환 객체를 생성합니다\n-var geocoder = new daum.maps.services.Geocoder();\n-var myAddress = [        ];\n-// 위 리스트 내부에 엑셀 파일의 가맹점 주소를 문자열 나열로 불러와야 합니다.\n+// // 인포윈도우를 생성합니다\n+// var infowindow = new kakao.maps.InfoWindow({\n+//     content : iwConte ...
#   {'filepath': 'map.html',
#    'latest_code': 'for (var i = 0; i < positions.length; i ++) {\n    // 마커 이미지의 이미지 크기 입니다\n    var imageSize = new kakao.maps.Size(24, 35); \n\n    // 마커 이미지를 생성합니다    \n    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);\n\n    // 마커를 생성합니다\n    var element = new kakao.maps.Marker({\n        map: map, // 마커를 표시할 지도\n        position: positions[i].latlng, // 마커를 표시할 위치\n        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다\n        image : markerImage // 마커 이미지 \n    }); \n    marker.push(element); // 마커 리스트에 개별 요소 추가\n}\n\n// 아래 코드는 위의 마커를 생성하는 코드에서 clickable: true 와 같이\n// 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\nmarker.setClickable(true);\n// 마커를 지도에 표시합니다.\nmarker.setMap(map);\n\n// // 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n// var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n//     iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n\n// 음식점 개별 인포윈도우 생성 \nvar iwContent = [\n    {content: \'<div style="padding:5px;">우돈갈비</div>\'},\n    {content: \'<div style="padding:5px;">갑돌네</div>\'},\n    {content: \'<div style="padding:5px;">청파 생고기</div>\'},\n],\niwRemoveable = true;\n;\n\n\n// // 기본 인포윈도우 생성\n// var infowindow = new kakao.maps.InfoWindow({\n//     content : iwContent,\n//     removable : iwRemoveable\n// });\n\n//음식점 개별 인포윈도우 생성\nvar infowindow = []; \n\nfor (var i = 0; i < positions.length; i ++) {\n  var iwelement = new kakao.maps.InfoWindow({\n    content : iwContent[i].content,\n    removable : iwRemoveable\n    });// 추가할 요소 값 생성\n  infowindow.push(iwelement); // 인포윈도우 리스트에 개별 요소 추가\n}\n\n\n// 마커에 클릭이벤트를 등록합니다\nfor (var i = 0; i < positions.length; i ++) {\n    kakao.maps.event.addListener(marker[i], \'click\', function() {\n      // 마커 위에 인포윈도우를 표시합니다\n      infowindow[i].open(map, marker[i]);  \n    });\n}\n\n\n\n</script>\n</body>\n</html>',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,102 @@\n+<!DOCTYPE html>\n+<html>\n+<head>\n+    <meta charset="utf-8">\n+    <title>map</title>\n+</head>\n+<body>\n+<div id="map" style="width:80%;height:350px;"></div>\n+<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=92cb297775fece43f08eacb009cd81b8"></script>\n+<script>\n+var mapContainer = document.getElementById(\'map\'), // 지도를 표시할 div  \n+    mapOption = { \n+        center: new kakao.maps.LatLng(37.5445, 126.9708), // 지도의 중심좌표\n+        level: 4 // 지도의 확대 레벨\n+    };\n+var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다\n+ \n+// 마커를 표시할 위치와 title 객체 배열입니다 \n+var positions = [\n+    {title: \'우돈갈비\', \n+        latlng: new kakao.maps.LatLng(37.5479, 126.9716)},\n+    {title: \'갑돌네\', \n+        latlng: new kakao.maps.LatLng(37.5502, 126.9697)},\n+    {title: \'청파 생고기\', \n+        latlng: new kakao.maps.LatLng(37.5501, 126.9697)},\n+];\n+\n+// 마커 이미지의 이미지 주소입니다\n+\n+//개별 마커 요소 생성\n+var marker = []\n+setClickable = true;\n+\n+for (var i = 0; i < positions.length; i ++) {\n+    // 마커 이미지의 이미지 크기 입니다\n+    var imageSize = new kakao.maps.Size(24, 35); \n+\n+    // 마커 이미지를 생성합니다    \n+    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);\n+\n+    // 마커를 생성합니다\n+    var element = new kakao.maps.Marker({\n+        map: map, // 마커를 표시할 지도\n+        position: positions[i].latlng, // 마커를 표시할 위치\n+        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다\n+        image : markerImage // 마커 이미지 \n+    }); \n+    marker.push(element); // 마커 리스트에 개별 요소 추가\n+}\n+\n+// 아래 코드는 위의 마커를 생성하는 코드에서 clickable: true 와 같이\n+// 마커를 클릭했을 때 지도의 클릭 이벤트가 발생하지 않도록 설정합니다\n+marker.setClickable(true);\n+// 마커를 지도에 표시합니다.\n+marker.setMap(map);\n+\n+// // 마커를 클릭했을 때 마커 위에 표시할 인포윈도우를 생성합니다\n+// var iwContent = \'<div style="padding:5px;">Hello World!</div>\', // 인포윈도우에 표출될 내용으로 HTML 문자열이나 document element가 가능합니다\n+//     iwRemoveable = true; // removeable 속성을 ture 로 설정하면 인포윈도우를 닫을 수 있는 x버튼이 표시됩니다\n+\n+// 음식점 개별 인포윈도우 생성 \n+var iwContent = [\n+    {content: \'<div style="padding:5px;">우돈갈비</div>\'},\n+    {content: \'<div style="padding:5px;">갑돌네</div>\'},\n+    {content: \'<div style="padding:5px;">청파 생고기</div>\'},\n+],\n+iwRemoveable = true;\n+;\n+\n+\n+// // 기본 인포윈도우 생성\n+// var infowindow = new kakao.maps.InfoWindow({\n+//     content : iwContent,\n+//     removable : iwRemoveable\n+// });\n+\n+//음식점 개별 인포윈도우 생성\n+var infowindow = []; \n+\n+for (var i = 0; i < positions.length; i ++) {\n+  var iwelement = new kakao.maps.InfoWindow({\n+    content : iwContent[i].content,\n+    removable : iwRemoveable\n+    });// 추가할 요소 값 생성\n+  infowindow.push(iwelement); // 인포윈도우 리스트에 개별 요소 추가\n+}\n+\n+\n+// 마커에 클릭이벤트를 등록합니다\n+for (var i = 0; i < positions.length; i ++) {\n+    kakao.maps.event.addListener(marker[i], \'click\', function() {\n+      // 마커 위에 인포윈도우를 표시합니다\n+      infowindow[i].open(map, marker[i]);  \n+    });\n+}\n+\n+\n+\n+</script>\n+</body>\n+</html>\n\\ No newline at end of file'}]},
#   {'filepath': 'index.html',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Create index.html',
#      'patch': '@@ -0,0 +1,39 @@\n+<!DOCTYPE html>\n+<html lang="en">\n+  <head>\n+    <meta charset="utf-8" />\n+    <link rel="icon" href="%PUBLIC_URL%/favicon.ico" />\n+    <meta name="viewport" content="width=device-width, initial-scale=1" />\n+    <meta name="theme-color" content="#000000" />\n+    <meta\n+      name="description"\n+      content="Web site created using create-react-app"\n+    />\n+    <link rel="apple-touch-icon" href="%PUBLIC_URL%/logo192.png" />\n+    <!--\n+      manifest.json provides metadata used when your web app is installed on a\n+    -->\n+    <link rel="manifest" href="%PUBLIC_URL%/manifest.json" />\n+    <!--\n+      Notice the use of %PUBLIC_URL% in the tags above.\n+      It will be replaced with the URL of the `public` folder during the build.\n+      Only files inside the `public` folder can be referenced from the HTML.\n+\n+      Unlike "/favicon.ico" or "favicon.ico", "%PUBLIC_URL%/favicon.ico" will\n+      work correctly both with client-side routing and a non-root public URL.\n+      Learn how to configure a non-root public URL by running `npm run build`.\n+    -->\n+    <title>Map Implementation</title>\n+\n+  </head>\n+  <body>\n+    <noscript>You need to enable JavaScript to run this app.</noscript>\n+    <div id="root"></div>\n+   \n+  </body>\n+  \n+</html>'}]},
#   {'filepath': 'ipsmap_appjs',
#    'latest_code': 'import \'./App.css\';\nimport { useEffect } from \'react\';\n\nfunction App() {\n  \n  //스크립트 파일 읽어오기\n  const new_script = src => { \n    return new Promise((resolve, reject) => { \n      const script = document.createElement(\'script\'); \n      script.src = src; \n      script.addEventListener(\'load\', () => { \n        resolve(); \n      }); \n      script.addEventListener(\'error\', e => { \n        reject(e); \n      }); \n      document.head.appendChild(script); \n    }); \n  };\n  \n  useEffect(() => { \n    //카카오맵 스크립트 읽어오기\n    \n    //스크립트 읽기 완료 후 카카오맵 설정\n    my_script.then(() => { \n      console.log(\'script loaded!!!\');  \n      const kakao = window[\'kakao\']; \n      kakao.maps.load(() => {\n        const mapContainer = document.getElementById(\'map\');\n        const options = { \n          center: new kakao.maps.LatLng(37.56000302825312, 126.97540593203321), //좌표설정\n          level: 3 \n        }; \n        const map = new kakao.maps.Map(mapContainer, options); //맵생성\n        //마커설정\n        const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321); \n        const marker = new kakao.maps.Marker({ \n          position: markerPosition\n        }); \n        marker.setMap(map); \n      });   \n    }); \n  }, []);\n\n  return (\n    <div className="App">\n      <div id="map" className="map"/>\n    </div>\n  );\n}\n\nexport default App;',
#    'patches': [{'commit_message': 'Create ipsmap_appjs',
#      'patch': '@@ -0,0 +1,53 @@\n+import \'./App.css\';\n+import { useEffect } from \'react\';\n+\n+function App() {\n+  \n+  //스크립트 파일 읽어오기\n+  const new_script = src => { \n+    return new Promise((resolve, reject) => { \n+      const script = document.createElement(\'script\'); \n+      script.src = src; \n+      script.addEventListener(\'load\', () => { \n+        resolve(); \n+      }); \n+      script.addEventListener(\'error\', e => { \n+        reject(e); \n+      }); \n+      document.head.appendChild(script); \n+    }); \n+  };\n+  \n+  useEffect(() => { \n+    //카카오맵 스크립트 읽어오기\n+    \n+    //스크립트 읽기 완료 후 카카오맵 설정\n+    my_script.then(() => { \n+      console.log(\'script loaded!!!\');  \n+      const kakao = window[\'kakao\']; \n+      kakao.maps.load(() => {\n+        const mapContainer = document.getElementById(\'map\');\n+        const options = { \n+          center: new kakao.maps.LatLng(37.56000302825312, 126.97540593203321), //좌표설정\n+          level: 3 \n+        }; \n+        const map = new kakao.maps.Map(mapContainer, options); //맵생성\n+        //마커설정\n+        const markerPosition = new kakao.maps.LatLng(37.56000302825312, 126.97540593203321); \n+        const marker = new kakao.maps.Marker({ \n+          position: markerPosition\n+        }); \n+        marker.setMap(map); \n+      });   \n+    }); \n+  }, []);\n+\n+  return (\n+    <div className="App">\n+      <div id="map" className="map"/>\n+    </div>\n+  );\n+}\n+\n+export default App;'}]},
#   {'filepath': 'public/BMI.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/Boy.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/favicon.ico',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/food.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/forest.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/friend.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/health.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/index.html',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,44 @@\n+<!DOCTYPE html>\n+<html lang="en">\n+  <head>\n+    <script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=33579a5447d1e9a38c0156bed39fe749"></script>\n+    <meta charset="utf-8" />\n+    <link rel="icon" href="%PUBLIC_URL%/friend.png" />\n+    <meta name="viewport" content="width=device-width, initial-scale=1" />\n+    <meta name="theme-color" content="#000000" />\n+    <meta\n+      name="description"\n+      content="Web site created using create-react-app"\n+    />\n+    <link rel="apple-touch-icon" href="%PUBLIC_URL%/logo192.png" />\n+    <!--\n+      manifest.json provides metadata used when your web app is installed on a\n+    -->\n+    <link rel="manifest" href="%PUBLIC_URL%/manifest.json" />\n+    <!--\n+      Notice the use of %PUBLIC_URL% in the tags above.\n+      It will be replaced with the URL of the `public` folder during the build.\n+      Only files inside the `public` folder can be referenced from the HTML.\n+\n+      Unlike "/favicon.ico" or "favicon.ico", "%PUBLIC_URL%/favicon.ico" will\n+      work correctly both with client-side routing and a non-root public URL.\n+      Learn how to configure a non-root public URL by running `npm run build`.\n+    -->\n+    <title>쑥쑥카드</title>\n+  </head>\n+  <body>\n+    <noscript>You need to enable JavaScript to run this app.</noscript>\n+    <div id="root"></div>\n+    <!--\n+      This HTML file is a template.\n+      If you open it directly in the browser, you will see an empty page.\n+\n+      You can add webfonts, meta tags, or analytics to this file.\n+      The build step will place the bundled scripts into the <body> tag.\n+\n+      To begin the development, run `npm start` or `yarn start`.\n+      To create a production bundle, use `npm run build` or `yarn build`.\n+    -->\n+  </body>\n+</html>'}]},
#   {'filepath': 'public/logo192.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/logo512.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/manifest.json',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,25 @@\n+{\n+  "short_name": "React App",\n+  "name": "Create React App Sample",\n+  "icons": [\n+    {\n+      "src": "favicon.ico",\n+      "sizes": "64x64 32x32 24x24 16x16",\n+      "type": "image/x-icon"\n+    },\n+    {\n+      "src": "logo192.png",\n+      "type": "image/png",\n+      "sizes": "192x192"\n+    },\n+    {\n+      "src": "logo512.png",\n+      "type": "image/png",\n+      "sizes": "512x512"\n+    }\n+  ],\n+  "start_url": ".",\n+  "display": "standalone",\n+  "theme_color": "#000000",\n+  "background_color": "#ffffff"\n+}'}]},
#   {'filepath': 'public/news.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/noonsong.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/profile.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'public/robots.txt',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,3 @@\n+User-agent: *\n+Disallow:'}]},
#   {'filepath': 'public/zandi.png',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'components/Dashboard.css',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,91 @@\n+.dashboard-nav {\n+  display: flex;\n+  justify-content: space-between;\n+  align-items: center;\n+  padding: 10px;\n+  background-color: #FAE951;\n+  position: fixed;\n+  top: 0;\n+  right: 0;\n+  left: 0;\n+  z-index: 9999;\n+  font-size: 20pt;\n+  font-weight: bold;\n+  color: #010D82;\n+  height: 70px;\n+}\n+\n+.sook{\n+  position:relative;\n+  top : -9px;\n+  font-size: 35pt;\n+  color: #279732;\n+}\n+\n+nav ul {\n+  position: absolute;\n+  top: 2px;\n+  right: 0;\n+  left: 0;\n+  display: flex;\n+  list-style: none;\n+}\n+\n+nav ul li + li {\n+  margin-left: 20px;\n+}\n+\n+nav a {\n+  color: #333;\n+  text-decoration: none;\n+}\n+\n+.active {\n+  color:#010D82;\n+  font-weight: bold;\n+}\n+\n+.dashboard-nav button{\n+  font-size: 20pt;\n+  background-color:#279732;\n+  color:#FAE951;\n+  border-radius: 0.5cm;\n+}\n+\n+/* src/style.css */\n+\n+.cost-container {\n+  position: absolute;\n+  width: 300px;\n+  top: 120px;\n+  right: 150px;\n+  background-color:  #a1efb350;\n+  border-radius: 0.5cm;\n+  padding: 50px;\n+}\n+\n+  .cost-container h2{\n+  font-size: 25pt;\n+  color:#010D82\n+}\n+\n+.news-container{\n+  position: absolute;\n+  width: 1250px;\n+  height: 600px;\n+  top: 100px;\n+  left: 50px;\n+  background-color: #f5f5f5;\n+\n+  padding: 50px;\n+  border-radius: 0.5cm;\n+\n+}\n+\n+.newsimage{\n+  position: absolute;\n+  top: 280px;\n+  right:150px;\n+\n+}\n+'}]},
#   {'filepath': 'components/Dashboard.js',
#    'latest_code': 'import React from \'react\';\nimport { NavLink, useNavigate } from \'react-router-dom\';\nimport \'./Dashboard.css\';\n\nfunction Dashboard() {\n  const navigate = useNavigate();\n\n  function handleLogout() {\n    navigate(\'/\');\n  }\n\n  return (\n    <div>\n      <nav className="dashboard-nav">\n        <ul>\n          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n          <li className=\'sook\'>쑥쑥카드</li>\n          <li>\n            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n          </li>\n          <li>\n            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n          </li>\n          <li>\n            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n          </li>\n          <li>\n            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n          </li>\n          <li>\n            <button onClick={handleLogout}>Logout</button>\n          </li>\n        </ul>\n      </nav>\n      <h1>홈 페이지</h1>\n      <div className="dashboard-container">\n        <div className="news-container">\n          <h1>서울특별시 - 아동급식카드 관련 최신 정보</h1>\n          <ul>\n            <br></br>\n            <br></br>\n          </ul>\n            <ul>\n            <h1>뉴스</h1>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <br></br>\n            <li>\n            </li>\n            <img src={process.env.PUBLIC_URL + \'/news.png\'} alt="newsimage" className="newsimage"/>\n          </ul>\n        </div>\n        <div className="cost-container">\n          <h2>아동급식카드 잔액조회</h2>\n        </div>\n      </div>\n    </div>\n  );\n}\n\nexport default Dashboard;',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,97 @@\n+import React from \'react\';\n+import { NavLink, useNavigate } from \'react-router-dom\';\n+import \'./Dashboard.css\';\n+\n+function Dashboard() {\n+  const navigate = useNavigate();\n+\n+  function handleLogout() {\n+    navigate(\'/\');\n+  }\n+\n+  return (\n+    <div>\n+      <nav className="dashboard-nav">\n+        <ul>\n+          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n+          <li className=\'sook\'>쑥쑥카드</li>\n+          <li>\n+            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n+          </li>\n+          <li>\n+            <button onClick={handleLogout}>Logout</button>\n+          </li>\n+        </ul>\n+      </nav>\n+      <h1>홈 페이지</h1>\n+      <div className="dashboard-container">\n+        <div className="news-container">\n+          <h1>서울특별시 - 아동급식카드 관련 최신 정보</h1>\n+          <ul>\n+            <br></br>\n+            <br></br>\n+          </ul>\n+            <ul>\n+            <h1>뉴스</h1>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <br></br>\n+            <li>\n+            </li>\n+            <img src={process.env.PUBLIC_URL + \'/news.png\'} alt="newsimage" className="newsimage"/>\n+          </ul>\n+        </div>\n+        <div className="cost-container">\n+          <h2>아동급식카드 잔액조회</h2>\n+        </div>\n+      </div>\n+    </div>\n+  );\n+}\n+\n+export default Dashboard;\n\\ No newline at end of file'}]},
#   {'filepath': 'components/Health.css',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,141 @@\n+.dashboard-nav {\n+    display: flex;\n+    justify-content: space-between;\n+    align-items: center;\n+    padding: 10px;\n+    background-color: #FAE951;\n+    position: fixed;\n+    top: 0;\n+    right: 0;\n+    left: 0;\n+    z-index: 9999;\n+    font-size: 20pt;\n+    font-weight: bold;\n+    color: #010D82;\n+    height: 70px;\n+  }\n+\n+  .sook{\n+    position:relative;\n+    top : -9px;\n+    font-size: 35pt;\n+    color: #279732;\n+  }\n+  \n+  nav ul {\n+    position: absolute;\n+    top: 2px;\n+    right: 0;\n+    left: 0;\n+    display: flex;\n+    list-style: none;\n+  }\n+  \n+  nav ul li + li {\n+    margin-left: 20px;\n+  }\n+  \n+  nav a {\n+    color: #333;\n+    text-decoration: none;\n+  }\n+  \n+  .active {\n+    color:#010D82;\n+    font-weight: bold;\n+  }\n+\n+  .dashboard-nav button{\n+    font-size: 20pt;\n+    background-color:#279732;\n+    color:#FAE951;\n+    border-radius: 0.5cm;\n+}\n+\n+  .calorie{\n+    position: absolute;\n+    width: 500px;\n+    height: 500px;\n+    top: 100px;\n+    left: 50px;\n+    background-color: #ffffff;\n+    border: 10px solid #f7890bb9;\n+    border-radius: 0.5cm;\n+    padding: 50px;\n+  }\n+\n+  .BMI{\n+        position: absolute;\n+        width: 500px;\n+        top: 100px;\n+        right: 70px;\n+        background-color: #ffffff;\n+        border: 10px solid #f7890bb9;\n+        padding: 50px;\n+        border-radius: 0.5cm;\n+      }\n+\n+.foodimage{\n+  position: absolute;\n+  top: 60px;\n+  left: 10px;\n+  width: min-content;\n+}\n+\n+.healthimage{\n+  position: absolute;\n+  top: 60px;\n+  right: 500px;\n+}\n+\n+.calorie h1{\n+  position: relative;\n+  left: 50px;\n+  top: 10px;\n+  border-radius: 1cm;\n+  width: 210px;\n+  background-color: limegreen;\n+  color:#010D82;\n+  \n+}\n+\n+.calorie label{\n+  font-weight: bold;\n+}\n+\n+.calorie button{\n+  font-weight: bold;\n+  background-color: #FAE951;\n+  color:#010D82;\n+  border-radius: 0.2cm;\n+}\n+\n+.BMI h1{\n+  position: relative;\n+  border-radius: 1cm;\n+  top: 10px;\n+  width: 180px;\n+  left: 70px;\n+  background-color: limegreen;\n+  color:#010D82;\n+\n+}\n+\n+.BMI label{\n+  font-weight: bold;\n+}\n+\n+.BMI button{\n+  font-weight: bold;\n+  background-color: #FAE951;\n+  color:#010D82;\n+  border-radius: 0.2cm;\n+}\n+\n+.bmiimage{\n+  position: absolute;\n+  height: 350px;\n+  width: 600px;\n+  top: 490px;\n+  right: 80px;\n+}\n\\ No newline at end of file'}]},
#   {'filepath': 'components/Health.js',
#    'latest_code': 'import React, { useState } from \'react\';\nimport { NavLink, useNavigate } from \'react-router-dom\';\nimport \'./Health.css\';\n\nfunction Health() {\n  const navigate = useNavigate();\n\n  function handleLogout() {\n    navigate(\'/\');\n  }\n\n  const [calories, setCalories] = useState(0);\n  const [foodItems, setFoodItems] = useState([]);\n  const [foodName, setFoodName] = useState(\'\');\n  const [foodCalorie, setFoodCalorie] = useState(\'\');\n\n  const addFoodItem = () => {\n    const newFoodItem = {\n      name: foodName,\n      calorie: Number(foodCalorie)\n    };\n    setFoodItems([...foodItems, newFoodItem]);\n    setCalories(calories + Number(foodCalorie));\n    setFoodName(\'\');\n    setFoodCalorie(\'\');\n  };\n\n  const [weight, setWeight] = useState(\'\');\n  const [height, setHeight] = useState(\'\');\n  const [bmi, setBMI] = useState(null);\n\n  const calculateBMI = () => {\n    const weightInKg = parseFloat(weight);\n    const heightInM = parseFloat(height) / 100;\n    const bmiValue = weightInKg / (heightInM * heightInM);\n    setBMI(bmiValue.toFixed(2));\n  };\n\n  return (\n    <div>\n      <nav className="dashboard-nav">\n        <ul>\n          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n          <li className=\'sook\'>쑥쑥카드</li>\n          <li>\n            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n          </li>\n          <li>\n            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n          </li>\n          <li>\n            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n          </li>\n          <li>\n            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n          </li>\n          <li>\n            <button onClick={handleLogout}>Logout</button>\n          </li>\n        </ul>\n      </nav>\n\n    <div className=\'calorie\'>\n        <img src={process.env.PUBLIC_URL + \'/food.png\'} alt="food" className=\'foodimage\' />\n        <h1>&nbsp;&nbsp;오늘 총 칼로리</h1>\n        <br></br>\n        <div>\n            <label htmlFor="foodName">음식 이름 : </label>\n            <input\n            type="text"\n            id="foodName"\n            value={foodName}\n            onChange={(e) => setFoodName(e.target.value)}\n            />\n        </div>\n        <br></br>\n        <div>\n            <label htmlFor="foodCalorie">칼로리 : </label>\n            <input\n            type="number"\n            id="foodCalorie"\n            value={foodCalorie}\n            onChange={(e) => setFoodCalorie(e.target.value)}\n            />\n        </div>\n        <br></br>\n        <button onClick={addFoodItem}>음식 추가</button>\n        <h3>음식 목록</h3>\n        <ul>\n            {foodItems.map((food, index) => (\n            <li key={index}>\n                {food.name} : {food.calorie}kcal\n            </li>\n            ))}\n        </ul>\n        <h2>총 칼로리 : {calories}kcal</h2>\n        </div>\n\n        <div className=\'BMI\'>\n        <img src={process.env.PUBLIC_URL + \'/health.png\'} alt="health" className=\'healthimage\' />\n        <h1>&nbsp;&nbsp;BMI 계산기</h1>\n        <br></br>\n            <div>\n                <label htmlFor="weight">체중(kg) : </label>\n                <input\n                type="number"\n                id="weight"\n                value={weight}\n                onChange={(e) => setWeight(e.target.value)}\n                />\n            </div>\n            <br></br>\n            <div>\n                <label htmlFor="height">키(cm) : </label>\n                <input\n                type="number"\n                id="height"\n                value={height}\n                onChange={(e) => setHeight(e.target.value)}\n                />\n            </div>\n            <br></br>\n            <button onClick={calculateBMI}>BMI 계산</button>\n            {bmi && <h3>BMI: {bmi}</h3>}\n                </div>\n\n                <img src={process.env.PUBLIC_URL + \'/BMI.p ...
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,135 @@\n+import React, { useState } from \'react\';\n+import { NavLink, useNavigate } from \'react-router-dom\';\n+import \'./Health.css\';\n+\n+function Health() {\n+  const navigate = useNavigate();\n+\n+  function handleLogout() {\n+    navigate(\'/\');\n+  }\n+\n+  const [calories, setCalories] = useState(0);\n+  const [foodItems, setFoodItems] = useState([]);\n+  const [foodName, setFoodName] = useState(\'\');\n+  const [foodCalorie, setFoodCalorie] = useState(\'\');\n+\n+  const addFoodItem = () => {\n+    const newFoodItem = {\n+      name: foodName,\n+      calorie: Number(foodCalorie)\n+    };\n+    setFoodItems([...foodItems, newFoodItem]);\n+    setCalories(calories + Number(foodCalorie));\n+    setFoodName(\'\');\n+    setFoodCalorie(\'\');\n+  };\n+\n+  const [weight, setWeight] = useState(\'\');\n+  const [height, setHeight] = useState(\'\');\n+  const [bmi, setBMI] = useState(null);\n+\n+  const calculateBMI = () => {\n+    const weightInKg = parseFloat(weight);\n+    const heightInM = parseFloat(height) / 100;\n+    const bmiValue = weightInKg / (heightInM * heightInM);\n+    setBMI(bmiValue.toFixed(2));\n+  };\n+\n+  return (\n+    <div>\n+      <nav className="dashboard-nav">\n+        <ul>\n+          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n+          <li className=\'sook\'>쑥쑥카드</li>\n+          <li>\n+            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n+          </li>\n+          <li>\n+            <button onClick={handleLogout}>Logout</button>\n+          </li>\n+        </ul>\n+      </nav>\n+\n+    <div className=\'calorie\'>\n+        <img src={process.env.PUBLIC_URL + \'/food.png\'} alt="food" className=\'foodimage\' />\n+        <h1>&nbsp;&nbsp;오늘 총 칼로리</h1>\n+        <br></br>\n+        <div>\n+            <label htmlFor="foodName">음식 이름 : </label>\n+            <input\n+            type="text"\n+            id="foodName"\n+            value={foodName}\n+            onChange={(e) => setFoodName(e.target.value)}\n+            />\n+        </div>\n+        <br></br>\n+        <div>\n+            <label htmlFor="foodCalorie">칼로리 : </label>\n+            <input\n+            type="number"\n+            id="foodCalorie"\n+            value={foodCalorie}\n+            onChange={(e) => setFoodCalorie(e.target.value)}\n+            />\n+        </div>\n+        <br></br>\n+        <button onClick={addFoodItem}>음식 추가</button>\n+        <h3>음식 목록</h3>\n+        <ul>\n+            {foodItems.map((food, index) => (\n+            <li key={index}>\n+                {food.name} : {food.calorie}kcal\n+            </li>\n+            ))}\n+        </ul>\n+        <h2>총 칼로리 : {calories}kcal</h2>\n+        </div>\n+\n+        <div className=\'BMI\'>\n+        <img src={process.env.PUBLIC_URL + \'/health.png\'} alt="health" className=\'healthimage\' />\n+        <h1>&nbsp;&nbsp;BMI 계산기</h1>\n+        <br></br>\n+            <div>\n+                <label htmlFor="weight">체중(kg) : </label>\n+                <input\n+                type="number"\n+                id="weight"\n+                value={weight}\n+                onChange={(e) => setWeight(e.target.value)}\n+                />\n+            </div>\n+            <br></br>\n+            <div>\n+                <label htmlFor="height">키(cm) : </label>\n+                <input\n+                type="number"\n+                id="height"\n+                value={height}\n+                onChange={(e) => setHeight(e.target.value)}\n+                />\n+            </div>\n+            <br></br>\n+            <button onClick={calculateBMI}>BMI 계산 ...
#   {'filepath': 'components/Login.css',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
# ...
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,100 @@\n+import React, { useState } from \'react\';\n+import { useNavigate } from \'react-router-dom\';\n+import \'./Login.css\';\n+\n+function Login() {\n+  const [cardNumber1, setCardNumber1] = useState(\'\');\n+  const [cardNumber2, setCardNumber2] = useState(\'\');\n+  const [cardNumber3, setCardNumber3] = useState(\'\');\n+  const [cardNumber4, setCardNumber4] = useState(\'\');\n+  const [password, setPassword] = useState(\'\');\n+  const [referralCode, setReferralCode] = useState(\'\');\n+  const navigate = useNavigate();\n+\n+  function handleSubmit(event) {\n+    event.preventDefault();\n+\n+    const cardNumber = cardNumber1 + cardNumber2 + cardNumber3 + cardNumber4;\n+\n+    if (cardNumber.length !== 16 || cardNumber1 === \'\' || cardNumber2 === \'\' || cardNumber3 === \'\' || cardNumber4 === \'\') {\n+      alert(\'카드번호를 정확하게 입력해주세요.\');\n+    } else {\n+      navigate(\'/dashboard\');\n+    }\n+  }\n+\n+  return (\n+    <div className="container">\n+      <img src={process.env.PUBLIC_URL + \'/boy.png\'} alt="boy" className="boyimage" />\n+      <h1 className="heading">쑥쑥카드</h1>\n+      <form onSubmit={handleSubmit} className="form">\n+        <div className="logincard">\n+          <label htmlFor="cardNumber1" className="label">카드번호 : </label>\n+          <input\n+            type="text"\n+            id="cardNumber1"\n+            maxLength={4}\n+            value={cardNumber1}\n+            onChange={(event) => setCardNumber1(event.target.value)}\n+            className="input"\n+          />\n+          &nbsp; - &nbsp;\n+          <input\n+            type="text"\n+            id="cardNumber2"\n+            maxLength={4}\n+            value={cardNumber2}\n+            onChange={(event) => setCardNumber2(event.target.value)}\n+            className="input"\n+          />\n+          &nbsp; - &nbsp;\n+          <input\n+            type="text"\n+            id="cardNumber3"\n+            maxLength={4}\n+            value={cardNumber3}\n+            onChange={(event) => setCardNumber3(event.target.value)}\n+            className="input"\n+          />\n+          &nbsp; - &nbsp;\n+          <input\n+            type="text"\n+            id="cardNumber4"\n+            maxLength={4}\n+            value={cardNumber4}\n+            onChange={(event) => setCardNumber4(event.target.value)}\n+            className="input"\n+          />\n+        </div>\n+        <div className="loginpassword">\n+          <label htmlFor="password" className="label">비밀번호 : </label>\n+          <input\n+            type="password"\n+            id="password"\n+            value={password}\n+            onChange={(event) => setPassword(event.target.value)}\n+            className="input"\n+          />\n+        </div>\n+        <div className="loginperson">\n+          <label htmlFor="referralCode" className="label">추천코드 : </label>\n+          <input\n+            type="text"\n+            id="referralCode"\n+            value={referralCode}\n+            onChange={(event) => setReferralCode(event.target.value)}\n+            className="input"\n+          />\n+        </div>\n+        <button \n+          type="submit" \n+          className="button"\n+        >\n+          로그인\n+        </button>\n+      </form>\n+    </div>\n+  );\n+}\n+\n+export default Login;'}]},
#   {'filepath': 'components/Map.css',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload', 'patch': ''}]},
#   {'filepath': 'components/Map.js',
#    'latest_code': 'import React, { useEffect } from \'react\'\n\nconst {kakao} = window;\n\nfunction Map(){\n\n  useEffect(()=>{\n    const container = document.getElementById(\'map\');\n    const options = {\n      center: new kakao.maps.LatLng(37.365264512305174, 127.10676860117488),\n      level: 3\n    };\n    //eslint-disable-next-line\n    const map = new kakao.maps.Map(container, options); \n    }, [])\n\n\n    return (\n      \n        \t<div id="map" style={{width:"1000px", height:"400px"}}></div> \n    )\n}\n\nexport default Map;',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,27 @@\n+//eslint-disable-next-line\n+/* global kakao */\n+import React, { useEffect } from \'react\'\n+\n+const {kakao} = window;\n+\n+function Map(){\n+\n+  useEffect(()=>{\n+    const container = document.getElementById(\'map\');\n+    const options = {\n+      center: new kakao.maps.LatLng(37.365264512305174, 127.10676860117488),\n+      level: 3\n+    };\n+    //eslint-disable-next-line\n+    const map = new kakao.maps.Map(container, options); \n+    }, [])\n+\n+\n+    return (\n+      \n+        \t<div id="map" style={{width:"1000px", height:"400px"}}></div> \n+    )\n+}\n+\n+export default Map;\n+'}]},
#   {'filepath': 'components/Mypage.css',
#    'latest_code': '',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,129 @@\n+.dashboard-nav {\n+  display: flex;\n+  justify-content: space-between;\n+  align-items: center;\n+  padding: 10px;\n+  background-color: #FAE951;\n+  position: fixed;\n+  top: 0;\n+  right: 0;\n+  left: 0;\n+  z-index: 9999;\n+  font-size: 20pt;\n+  font-weight: bold;\n+  color: #010D82;\n+  height: 70px;\n+}\n+\n+.sook{\n+  position:relative;\n+  top : -9px;\n+  font-size: 35pt;\n+  color: #279732;\n+}\n+\n+nav ul {\n+  position: absolute;\n+  top: 2px;\n+  right: 0;\n+  left: 0;\n+  display: flex;\n+  list-style: none;\n+}\n+\n+nav ul li + li {\n+  margin-left: 20px;\n+}\n+\n+nav a {\n+  color: #333;\n+  text-decoration: none;\n+}\n+\n+.active {\n+  color:#F0656B;\n+  font-weight: bold;\n+}\n+\n+.dashboard-nav button{\n+  font-size: 20pt;\n+  background-color:#279732;\n+  color:#FAE951;\n+  border-radius: 0.5cm;\n+}\n+\n+.mypage-container {\n+  display: flex;\n+  align-items: flex-start;\n+}\n+\n+.profile-pic {\n+  margin-right: 20px;\n+}\n+\n+.user-info {\n+  flex-grow: 1;\n+}\n+\n+.userinfochange {\n+  position: absolute;\n+  width: 500px;\n+  height: 450px;\n+  top: 110px;\n+  right: 50px;\n+  background-color: #ffffff;\n+  border: 5px solid #010D82;\n+  padding: 50px;\n+  color:#333;\n+  border-radius: 0.5cm;\n+  font-weight: bold;\n+  font-size: 15pt;\n+}\n+\n+.userinfo{\n+  position: absolute;\n+  width: 600px;\n+  height: 450px;\n+  top: 110px;\n+  left: 50px;\n+  background-color: #ffffff;\n+  border: 5px solid #010D82;\n+  padding: 50px;\n+  color:#010D82;\n+  border-radius: 0.5cm;\n+  font-weight: bold;\n+  font-size: 15pt;\n+}\n+.userinfo h2{\n+  color:#010D82;\n+  border-radius: 0.5cm;\n+  padding: 10px;\n+\n+}\n+.userinfochange h2{\n+  color:#010D82;\n+  top: 100px;\n+  border-radius: 0.5cm;\n+  padding: 10px;\n+}\n+.profileimage{\n+  position: absolute;\n+  top: 50px;\n+  left: 50px;\n+}\n+\n+.userinfochange button{\n+  font-weight: bold;\n+  background-color: #FAE951;\n+  color:#010D82;\n+  border-radius: 0.2cm;\n+}\n+\n+.userinfochange label{\n+  color:#010D82\n+}\n+\n+.zandiimage{\n+  position: absolute;\n+  top: 370px;\n+}\n\\ No newline at end of file'}]},
#   {'filepath': 'components/Mypage.js',
#    'latest_code': 'import React, { useState } from \'react\';\nimport { NavLink} from \'react-router-dom\';\nimport \'./Mypage.css\';\n\nfunction Mypage() {\n  const [userInfo, setUserInfo] = useState({\n    nickname: \'\',\n    email: \'\',\n    cardnumber: \'\',\n    birth: \'\',\n    phone: \'\',\n    profilePic: \'\',\n  });\n  \n\n  function handleUserInfoUpdate(event) {\n    event.preventDefault();\n\n    const updatedInfo = {\n      nickname: event.target.name.value,\n      email: event.target.email.value,\n      profilePic: event.target.profilePic.files[0],\n      cardnumber: event.target.cardnumber.value,\n      birth: event.target.birth.value,\n      phone: event.target.phone.value,\n    };\n\n    setUserInfo(updatedInfo);\n  }\n\n  function handleLogout() {\n    window.location.href = \'/\';\n  }\n\n\n  return (\n    <div>\n      <nav className="dashboard-nav">\n        <ul>\n          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n          <li className=\'sook\'>쑥쑥카드</li>\n          <li>\n            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n          </li>\n          <li>\n            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n          </li>\n          <li>\n            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n          </li>\n          <li>\n            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n          </li>\n          <li>\n            <button onClick={handleLogout}>Logout</button>\n          </li>\n        </ul>\n      </nav>\n\n      <div className=\'userinfo\'>\n      <div style={{ display: \'flex\', alignItems: \'center\' }}>\n        <img src={userInfo.profilePic ? URL.createObjectURL(userInfo.profilePic) : \'noonsong.png\'} alt="프로필 사진" style={{ marginRight: \'3em\' }} />\n        <div>\n            <h2>내 정보</h2>\n          <p>닉네임: {userInfo.nickname}</p>\n          <p>이메일: {userInfo.email}</p>\n          <p>카드번호: {userInfo.cardnumber}</p>\n          <p>생년월일: {userInfo.birth}</p>\n          <p>핸드폰번호: {userInfo.phone}</p>\n        </div>\n      </div>\n      </div>\n      <img src={process.env.PUBLIC_URL + \'/zandi.png\'} alt="잔디 사진" className="zandiimage"/>\n      <div className=\'userinfochange\'>\n        <h2>사용자 정보 수정</h2>\n        <form onSubmit={handleUserInfoUpdate}>\n          <label>\n            닉네임 : \n            &nbsp;\n            <input type="text" name="name" defaultValue={userInfo.nickname} />\n          </label>\n          <br></br>\n          <br></br>\n          <label>\n            이메일 :\n            &nbsp;\n            <input type="email" name="email" defaultValue={userInfo.email} />\n          </label>\n          <br></br>\n          <br></br>\n          <label>\n            카드번호 :\n            &nbsp;\n            <input type="text" name="cardnumber" defaultValue={userInfo.cardnumber} />\n          </label>\n          <br></br>\n          <br></br>\n          <label>\n            생년월일 :\n            &nbsp;\n            <input type="date" name="birth" defaultValue={userInfo.birth} />\n          </label>\n          <br></br>\n          <br></br>\n           <label>\n            핸드폰번호 :\n            &nbsp;\n            <input type="tel" name="phone" defaultValue={userInfo.phone} />\n          </label>\n          <br></br>\n          <br></br>\n          <label>\n            프로필 사진 :\n            &nbsp;\n            <input type="file" name="profilePic" accept="image/*" onChange={(event) => setUserInfo({userInfo, profilePic: event.target.files[0] })} />\n          </label>\n          <br></br>\n          <br></br>\n          <button type="submit">수정</button>\n        </form>\n      </div>\n    </div>\n  );\n}\n\nexport default Mypage;',
#    'patches': [{'commit_message': 'Add files via upload',
#      'patch': '@@ -0,0 +1,126 @@\n+import React, { useState } from \'react\';\n+import { NavLink} from \'react-router-dom\';\n+import \'./Mypage.css\';\n+\n+function Mypage() {\n+  const [userInfo, setUserInfo] = useState({\n+    nickname: \'\',\n+    email: \'\',\n+    cardnumber: \'\',\n+    birth: \'\',\n+    phone: \'\',\n+    profilePic: \'\',\n+  });\n+  \n+\n+  function handleUserInfoUpdate(event) {\n+    event.preventDefault();\n+\n+    const updatedInfo = {\n+      nickname: event.target.name.value,\n+      email: event.target.email.value,\n+      profilePic: event.target.profilePic.files[0],\n+      cardnumber: event.target.cardnumber.value,\n+      birth: event.target.birth.value,\n+      phone: event.target.phone.value,\n+    };\n+\n+    setUserInfo(updatedInfo);\n+  }\n+\n+  function handleLogout() {\n+    window.location.href = \'/\';\n+  }\n+\n+\n+  return (\n+    <div>\n+      <nav className="dashboard-nav">\n+        <ul>\n+          <li><img src={process.env.PUBLIC_URL + \'/friend.png\'} alt="friend" /></li>\n+          <li className=\'sook\'>쑥쑥카드</li>\n+          <li>\n+            <NavLink to="/dashboard" activeClassName="active">홈</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/map" activeClassName="active">가맹점 지도 조회</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/health" activeClassName="active">나의 건강</NavLink>\n+          </li>\n+          <li>\n+            <NavLink to="/mypage" activeClassName="active">마이페이지</NavLink>\n+          </li>\n+          <li>\n+            <button onClick={handleLogout}>Logout</button>\n+          </li>\n+        </ul>\n+      </nav>\n+\n+      <div className=\'userinfo\'>\n+      <div style={{ display: \'flex\', alignItems: \'center\' }}>\n+        <img src={userInfo.profilePic ? URL.createObjectURL(userInfo.profilePic) : \'noonsong.png\'} alt="프로필 사진" style={{ marginRight: \'3em\' }} />\n+        <div>\n+            <h2>내 정보</h2>\n+          <p>닉네임: {userInfo.nickname}</p>\n+          <p>이메일: {userInfo.email}</p>\n+          <p>카드번호: {userInfo.cardnumber}</p>\n+          <p>생년월일: {userInfo.birth}</p>\n+          <p>핸드폰번호: {userInfo.phone}</p>\n+        </div>\n+      </div>\n+      </div>\n+      <img src={process.env.PUBLIC_URL + \'/zandi.png\'} alt="잔디 사진" className="zandiimage"/>\n+      <div className=\'userinfochange\'>\n+        <h2>사용자 정보 수정</h2>\n+        <form onSubmit={handleUserInfoUpdate}>\n+          <label>\n+            닉네임 : \n+            &nbsp;\n+            <input type="text" name="name" defaultValue={userInfo.nickname} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+          <label>\n+            이메일 :\n+            &nbsp;\n+            <input type="email" name="email" defaultValue={userInfo.email} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+          <label>\n+            카드번호 :\n+            &nbsp;\n+            <input type="text" name="cardnumber" defaultValue={userInfo.cardnumber} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+          <label>\n+            생년월일 :\n+            &nbsp;\n+            <input type="date" name="birth" defaultValue={userInfo.birth} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+           <label>\n+            핸드폰번호 :\n+            &nbsp;\n+            <input type="tel" name="phone" defaultValue={userInfo.phone} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+          <label>\n+            프로필 사진 :\n+            &nbsp;\n+            <input type="file" name="profilePic" accept="image/*" onChange={(event) => setUserInfo({userInfo, profilePic: event.target.files[0] })} />\n+          </label>\n+          <br></br>\n+          <br></br>\n+          <button type="submit">수정</button>\n+        </form>\n+      </div>\n+    </div>\n+  );\n+}\n+\n+export default Mypage;\n\\ No newline at end of file'}]}]}
